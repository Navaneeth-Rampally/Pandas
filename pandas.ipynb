# %% [markdown]
# Importing pandas library.

# %%
import pandas as pd

# %% [markdown]
# **Reading a excel datset**

# %%
df = pd.read_excel(r"D:\CPSIT\Practice\Pandas\loan_data.xlsx")

# %% [markdown]
# **Reading a csv dataset**

# %%
pd.read_csv(r"D:\CPSIT\Practice\Pandas\Sales_Data.csv")
# Out:
#                                  Region               Country   Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %% [markdown]
# **head()**- it is used to print first five rows of a table

# %%
df.head()
# Out:
#                               Region               Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12/20/2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7/26/2010
# 2       Offline              C  09-12-2011  478051030.0   9/29/2011
# 3       Offline              L   5/13/2010  892599952.0   6/15/2010
# 4       Offline              C   7/20/2015  571902596.0   7/27/2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# ...

# %% [markdown]
# **tail()**- it is used to print last five rows of a table.

# %%
df.tail()
# Out:
#                             Region      Country   Item_Type Sales_Channel  \
# 4995         Australia and Oceania  New Zealand   Household       Offline
# 4996  Middle East and North Africa   Azerbaijan     Clothes       Offline
# 4997                          Asia      Myanmar   Baby Food       Offline
# 4998                        Europe      Finland     Clothes        Online
# 4999            Sub-Saharan Africa     Tanzania  Vegetables        Online
#
#      Order_Priority  Order_Date     Order_ID   Ship_Date  Units_Sold  \
# 4995              C  04-03-2015  217984473.0   4/20/2015        5305
# 4996              L   8/17/2014  169748055.0  10-02-2014        1077
# 4997              H  11/23/2016          NaN  12-10-2016        5204
# 4998              L   4/22/2014          NaN  05-11-2014        9410
# 4999              L  07-08-2011          NaN  08-07-2011        2450
#
#       Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# ...

# %% [markdown]
# **shape**- it is used to know how many rows and columns are there in a dataset

# %%
df.shape
# Out:
# (5000, 14)

# %% [markdown]
# **columns()**- It is used to print all the column present in the dataset.

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Order_Date', 'Order_ID', 'Ship_Date', 'Units_Sold',
#        'Unit_SellingPrice', 'Unit_MakingCost', 'Total_Revenue', 'Total_Cost',
#        'Total_Profit'],
#       dtype='str')

# %% [markdown]
# **Info()**- it it used to get entire information of a dataset like how many types of values are there, null, not-null values etc..

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   str
#  1   Country            5000 non-null   str
#  2   Item_Type          4989 non-null   str
#  3   Sales_Channel      5000 non-null   str
#  4   Order_Priority     5000 non-null   str
#  5   Order_Date         5000 non-null   str
#  6   Order_ID           4997 non-null   float64
#  7   Ship_Date          5000 non-null   str
#  8   Units_Sold         5000 non-null   int64
#  9   Unit_SellingPrice  5000 non-null   float64
#  10  Unit_MakingCost    5000 non-null   float64
#  11  Total_Revenue      5000 non-null   float64
#  12  Total_Cost         5000 non-null   float64
#  13  Total_Profit       5000 non-null   float64
# dtypes: float64(6), int64(1), str(7)
# memory usage: 547.0 KB

# %% [markdown]
# **Data selection using iloc and loc**

# %%
df.loc[0:1,'Region':'Country']
# Out:
#                               Region               Country
# 0  Central America and the Caribbean  Antigua and Barbuda
# 1  Central America and the Caribbean                Panama

# %%
df.iloc[0:2,0:2]
# Out:
#                               Region               Country
# 0  Central America and the Caribbean  Antigua and Barbuda
# 1  Central America and the Caribbean                Panama

# %% [markdown]
# **Handling null values**

# %%
#checking null values using isnull()
df.isnull().sum()
# Out:
# Region                0
# Country               0
# Item_Type            11
# Sales_Channel         0
# Order_Priority        0
# Order_Date            0
# Order_ID              3
# Ship_Date             0
# Units_Sold            0
# Unit_SellingPrice     0
# Unit_MakingCost       0
# Total_Revenue         0
# Total_Cost            0
# Total_Profit          0
# dtype: int64

# %%
#Dropping null values using dropna()
df.dropna()
# Out:
#                                  Region               Country  Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1     Central America and the Caribbean                Panama     Snacks
# 2                                Europe        Czech Republic  Beverages
# 3                                  Asia           North Korea     Cereal
# 4                                  Asia             Sri Lanka     Snacks
# ...                                 ...                   ...        ...
# 4992       Middle East and North Africa                  Iran    Clothes
# 4993                             Europe               Denmark    Clothes
# 4994                 Sub-Saharan Africa               Liberia  Cosmetics
# 4995              Australia and Oceania           New Zealand  Household
# 4996       Middle East and North Africa            Azerbaijan    Clothes
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
#Filling null values using fillna()
df.fillna(0)
# Out:
#                                  Region               Country   Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   str
#  1   Country            5000 non-null   str
#  2   Item_Type          4989 non-null   str
#  3   Sales_Channel      5000 non-null   str
#  4   Order_Priority     5000 non-null   str
#  5   Order_Date         5000 non-null   str
#  6   Order_ID           4997 non-null   float64
#  7   Ship_Date          5000 non-null   str
#  8   Units_Sold         5000 non-null   int64
#  9   Unit_SellingPrice  5000 non-null   float64
#  10  Unit_MakingCost    5000 non-null   float64
#  11  Total_Revenue      5000 non-null   float64
#  12  Total_Cost         5000 non-null   float64
#  13  Total_Profit       5000 non-null   float64
# dtypes: float64(6), int64(1), str(7)
# memory usage: 547.0 KB

# %% [markdown]
# **Type conversions**

# %%
df['Units_Sold']= df['Units_Sold'].astype('float')

# %%
df.head()
# Out:
#                               Region               Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12/20/2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7/26/2010
# 2       Offline              C  09-12-2011  478051030.0   9/29/2011
# 3       Offline              L   5/13/2010  892599952.0   6/15/2010
# 4       Offline              C   7/20/2015  571902596.0   7/27/2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# ...

# %% [markdown]
# **Removing duplicate rows from table**

# %%
df.drop_duplicates()
